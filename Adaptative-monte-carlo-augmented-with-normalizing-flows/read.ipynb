# %%
from energy_package.energy_package import XY
from plot_animation_package.plot_animation_package import XYd2n3
from os.path import dirname
import torch
import matplotlib.pyplot as plt

# %%
model_file = r'C:\Users\samue\Documents\GitHub\ML_project\Adaptative-monte-carlo-augmented-with-normalizing-flows\saved_models\XYd2n3-multivariate_normal-LayeredPlanarFlow-beta0-h0-J1\XYd2n3-multivariate_normal-LayeredPlanarFlow-beta0-h0-J1'

# %%
path = dirname(model_file)
history = torch.load(path + '\\history.pt').detach()

fig, ax = plt.subplots(figsize = (5,10))
ax.imshow(history)
ax.set_xlabel('initial point')
ax.set_ylabel('iteration')
fig.savefig(path + '\\history.png')

# %%
trajectory_id = 0
U = XY.XYd2n3
XYd2n3.simple_plot(model_file, trajectory_id, U)
#XYd2n2.trajectory(model_file, trajectory_id, U)
# Out:
# {'beta': 0.0, 'n': 10, 'N': 8000, 'time_step': 0.1, 'k_max': 200, 'k_lang': 10, 'epsilon': 0.01, 'energy_parameters': [1.0, 1.0, 0.0, 3.141592653589793]}

# %%
XYd2n1.animation(model_file, n, k_max, array_of_model_configurations, history)
